# %% [markdown]
# # <h1 align = "center">JCIA Hackathon 2025</h1>
# # <h1 align = "center">Tri Automatique des Prunes</h1>
#
# <table align="center">
#   <thead>
#     <tr>
#       <th>Noms</th>
#       <th>Prenoms</th>
#       <th>Matricule</th>
#     </tr>
#   </thead>
#   <tbody bgcolor='green' align='center'>
#     <tr>
#       <td>LONTSI LAMBOU</td>
#       <td>RONALDINO</td>
#       <td>lontsilambou@gmail.com</td>
#     </tr>
#     <tr>
#       <td>FETUE FOKO </td>
#       <td>NATHANAEL</td>
#       <td>nathanaelfetue1237@gmail.com</td>
#     </tr>
#      <tr>
#       <td>TCHIAZE FOUOSSO</td>
#       <td>ROMERO</td>
#       <td>21T2474</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # <h3 align = "center">Importation des bibliotheques</h3>

# %%
# 1. Importation des bibliothèques nécessaires
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import glob
import cv2
from tqdm import tqdm

# TensorFlow et Keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalFocalCrossentropy
from keras.utils import to_categorical

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# Out:
# 2025-04-17 07:25:06.593555: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-17 07:25:06.621813: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-17 07:25:06.621850: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-17 07:25:06.621869: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 07:25:06.627150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-17 07:25:07.218065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # <h3 align = "center">configuration du GPU SI DISPONIBLE</h3>

# %%
# Configuration pour utiliser le GPU si disponible
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)
# Out:
# 2025-04-17 07:25:10.054839: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# # <h3 align = "center">Définir les paramètres</h3>

# %%
# Définir les paramètres
SEED = 32
IMG_SIZE = 324  # Taille d'image pour MobileNetV2
BATCH_SIZE = 16
EPOCHS = 15  # Nombre d'époques
LEARNING_RATE = 0.0001  # Taux d'apprentissage réduit

# 2.

# %% [markdown]
# # <h3 align = "center">Exploration des données</h3>

# %%
# 2. Exploration des données

# Chemin vers ton fichier CSV sur Kaggle
file_path = '/kaggle/input/african-plums-quality-and-defect-assessment-data/african_plums_dataset/organized_plums_data_new.csv'

# Lecture du fichier CSV
df = pd.read_csv(file_path)
# 2.1 Chargement du fichier CSV

print("Aperçu des données:")
print(df.head())
print("\nInformations sur le DataFrame:")
print(df.info())
# Out:
# Aperçu des données:
#          Image ID      Label Defect Type
# 0  bruised_plum_1  defective     bruised
# 1  bruised_plum_2  defective     bruised
# 2  bruised_plum_3  defective     bruised
# 3  bruised_plum_4  defective     bruised
# 4  bruised_plum_5  defective     bruised
#
# Informations sur le DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4507 entries, 0 to 4506
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Image ID     4507 non-null   object
#  1   Label        4507 non-null   object
#  2   Defect Type  4507 non-null   object
# dtypes: object(3)
# memory usage: 105.8+ KB
# None

# %%
# 2.2 Analyse de la distribution des classes
print("\nDistribution des classes:")
class_distribution = df['Defect Type'].value_counts()
print(class_distribution)

# Visualiser la distribution des classes
plt.figure(figsize=(12, 6))
class_counts = df['Defect Type'].value_counts()
sns.barplot(x=class_counts.index, y=class_counts.values)
plt.title('Distribution des classes de prunes')
plt.xlabel('Type de défaut')
plt.ylabel('Nombre d\'images')
plt.xticks(rotation=45)

# Ajouter les valeurs et pourcentages
total = len(df)
for i, v in enumerate(class_counts.values):
    percentage = v / total * 100
    plt.text(i, v + 30, f"{v}\n({percentage:.1f}%)", ha='center')

plt.tight_layout()
plt.savefig('class_distribution.png')
plt.close()
# Out:
# Distribution des classes:
# Defect Type
# unaffected    1721
# unripe         826
# spotted        759
# rotten         720
# bruised        319
# cracked        162
# Name: count, dtype: int64

# %%
# 3. Prétraitement des données
# 3.1 Définition des chemins d'accès et des classes
# ⚙️ Chemins de base
data_dir = Path("/kaggle/input/african-plums-quality-and-defect-assessment-data/african_plums_dataset/african_plums")

# Utiliser les classes exactes présentes dans les données
classes = ['unaffected', 'unripe', 'spotted', 'rotten', 'bruised', 'cracked']
print(f"\nClasses identifiées: {classes}")

# Distribution des classes
print("\nDistribution des classes:")
for cls in classes:
    count = df[df['Defect Type'] == cls].shape[0]
    print(f"{cls}: {count} images ({count/len(df)*100:.1f}%)")
# Out:
# Classes identifiées: ['unaffected', 'unripe', 'spotted', 'rotten', 'bruised', 'cracked']
#
# Distribution des classes:
# unaffected: 1721 images (38.2%)
# unripe: 826 images (18.3%)
# spotted: 759 images (16.8%)
# rotten: 720 images (16.0%)
# bruised: 319 images (7.1%)
# cracked: 162 images (3.6%)

# %%
# 3.2 Vérification de l'existence des dossiers et comptage des images
image_counts = {}
for cls in classes:
    cls_path = os.path.join(base_dir, cls)
    if os.path.exists(cls_path):
        image_counts[cls] = len(os.listdir(cls_path))
    else:
        print(f"Le dossier pour la classe {cls} n'existe pas: {cls_path}")
        image_counts[cls] = 0

print("\nNombre d'images par classe:")
for cls, count in image_counts.items():
    print(f"{cls}: {count} images")
# Out:
# Nombre d'images par classe:
# unaffected: 1721 images
# unripe: 826 images
# spotted: 759 images
# rotten: 720 images
# bruised: 319 images
# cracked: 162 images

# %% [markdown]
# # <h3 align = "center">Fonction de prétraitement pour les images</h3>

# %%
# 3.3 Fonction de prétraitement pour les images
# Fonction personnalisée pour le prétraitement
def preprocess_image(img):
    try:
        # Vérifier le type et la forme de l'image d'entrée
        if isinstance(img, str):
            print(f"Erreur: img est une chaîne de caractères: {img}")
            # Créer une image noire à la place
            return np.zeros((IMG_SIZE, IMG_SIZE, 3))
        
        if img is None:
            print("Erreur: img est None")
            return np.zeros((IMG_SIZE, IMG_SIZE, 3))
        
        # Convertir en RGB si nécessaire
        if len(img.shape) == 2:  # Image en niveaux de gris
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        elif img.shape[-1] == 4:  # Image RGBA
            img = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)
        elif img.shape[-1] != 3:  # Autre format
            print(f"Format d'image non standard: {img.shape}")
            # Créer une image RGB à partir des données
            if len(img.shape) > 2:
                img = img[:, :, :3]  # Prendre les 3 premiers canaux
            else:
                img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        
        # S'assurer que l'image est au format uint8
        if img.dtype != np.uint8:
            if img.max() <= 1.0:
                img = (img * 255).astype(np.uint8)
            else:
                img = img.astype(np.uint8)
        
        # Appliquer des traitements simples
        # Redimensionner
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        
        # Normaliser les valeurs de pixel
        img = img / 255.0
        
        return img
    
    except Exception as e:
        print(f"Erreur dans preprocess_image: {e}")
        # En cas d'erreur, retourner une image noire
        return np.zeros((IMG_SIZE, IMG_SIZE, 3))

# %% [markdown]
# # <h3 align = "center">FONCTION POUR L'AUGMENTATION DES DONNEES </h3>

# %%
# 4. Préparation des données pour le modèle
# 4.1 Division des données en ensembles d'entraînement, validation et test (70-15-15)
from sklearn.model_selection import train_test_split

# Définir le générateur principal sans division validation intégrée
# Augmentation plus agressive pour les classes minoritaires
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image,
    rotation_range=30,                # Augmenter à 30 degrés
    width_shift_range=0.3,            # Augmenter à 0.3
    height_shift_range=0.3,           # Augmenter à 0.3
    shear_range=0.3,                  # Augmenter à 0.3
    zoom_range=0.3,                   # Augmenter à 0.3
    horizontal_flip=True,
    vertical_flip=True,               # Ajouter le retournement vertical
    brightness_range=[0.7, 1.3],      # Ajouter variation de luminosité
    fill_mode='nearest'
)

# Générateur pour validation et test (sans augmentation)
eval_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_image
)

# Obtenir toutes les images et leurs classes
import glob
image_paths = []
image_classes = []

for cls in classes:
    cls_path = os.path.join(base_dir, cls)
    if os.path.exists(cls_path):
        for img_file in glob.glob(os.path.join(cls_path, '*.jpg')) + \
                        glob.glob(os.path.join(cls_path, '*.png')) + \
                        glob.glob(os.path.join(cls_path, '*.jpeg')):
            image_paths.append(img_file)
            image_classes.append(cls)

# Créer un DataFrame pour faciliter la division
image_df = pd.DataFrame({
    'path': image_paths,
    'class': image_classes
})

# Vérifier la distribution des classes dans le dataset complet
print("\nDistribution des classes dans le dataset complet:")
print(image_df['class'].value_counts())
# Out:
# Distribution des classes dans le dataset complet:
# class
# unaffected    1721
# unripe         826
# spotted        759
# rotten         720
# bruised        319
# cracked        162
# Name: count, dtype: int64

# %% [markdown]
# # <h3 align = "center">Division des données en ensembles d'entraînement, validation et test (70-15-15)</h3>

# %%
# Première division : 85% pour train+validation, 15% pour test
train_val_df, test_df = train_test_split(
    image_df, 
    test_size=0.15, 
    stratify=image_df['class'],
    random_state=SEED
)

# Deuxième division : diviser train_val_df en 82.35% train (70% du total) et 17.65% validation (15% du total)
train_df, val_df = train_test_split(
    train_val_df, 
    test_size=0.1765,  # 15/85 = 0.1765
    stratify=train_val_df['class'],
    random_state=SEED
)

print(f"\nRépartition des données:")
print(f"Entraînement: {len(train_df)} images ({len(train_df)/len(image_df)*100:.1f}%)")
print(f"Validation: {len(val_df)} images ({len(val_df)/len(image_df)*100:.1f}%)")
print(f"Test: {len(test_df)} images ({len(test_df)/len(image_df)*100:.1f}%)")

# Vérifier la distribution des classes dans chaque ensemble
print("\nDistribution des classes dans l'ensemble d'entraînement:")
print(train_df['class'].value_counts())
print("\nDistribution des classes dans l'ensemble de validation:")
print(val_df['class'].value_counts())
print("\nDistribution des classes dans l'ensemble de test:")
print(test_df['class'].value_counts())
# Out:
# Répartition des données:
# Entraînement: 3154 images (70.0%)
# Validation: 676 images (15.0%)
# Test: 677 images (15.0%)
#
# Distribution des classes dans l'ensemble d'entraînement:
# class
# unaffected    1204
# unripe         578
# spotted        531
# rotten         504
# bruised        223
# cracked        114
# Name: count, dtype: int64
#
# Distribution des classes dans l'ensemble de validation:
# class
# unaffected    258
# unripe        124
# spotted       114
# rotten        108
# bruised        48
# cracked        24
# Name: count, dtype: int64
#
# Distribution des classes dans l'ensemble de test:
# class
# unaffected    259
# unripe        124
# spotted       114
# rotten        108
# bruised        48
# cracked        24
# Name: count, dtype: int64

# %% [markdown]
# # <h3 align = "center"> Équilibrer les classes par surreprésentation des classes minoritaires avec l'augmentation
# </h3>

# %%
# 4.2 Gestion du déséquilibre des classes dans l'ensemble d'entraînement
# Équilibrer les classes par surreprésentation des classes minoritaires

# Déterminer la taille de la classe majoritaire
max_class_count = train_df['class'].value_counts().max()

# Préparer un DataFrame équilibré
balanced_train_df = train_df.copy()

# Pour chaque classe minoritaire, ajouter des copies jusqu'à atteindre la taille de la classe majoritaire
for cls, count in train_df['class'].value_counts().items():
    if count < max_class_count:
        # Calculer combien d'échantillons supplémentaires sont nécessaires
        samples_to_add = max_class_count - count
        
        # Obtenir les échantillons de cette classe
        class_samples = train_df[train_df['class'] == cls]
        
        # Ajouter des copies (avec remplacement si nécessaire)
        additional_samples = class_samples.sample(n=samples_to_add, replace=True, random_state=SEED)
        
        # Combiner avec le DataFrame équilibré
        balanced_train_df = pd.concat([balanced_train_df, additional_samples])

print("\nTaille du dataset d'entraînement après équilibrage:", len(balanced_train_df))
print("Distribution des classes après équilibrage:")
print(balanced_train_df['class'].value_counts())
# Out:
# Taille du dataset d'entraînement après équilibrage: 7224
# Distribution des classes après équilibrage:
# class
# unaffected    1204
# rotten        1204
# spotted       1204
# cracked       1204
# unripe        1204
# bruised       1204
# Name: count, dtype: int64

# %%
# 4.3 Création des générateurs pour l'entraînement et l'évaluation
train_generator = train_datagen.flow_from_dataframe(
    dataframe=balanced_train_df,
    directory=None,  # Les chemins complets sont déjà dans 'path'
    x_col='path',
    y_col='class',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=SEED
)

validation_generator = eval_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=None,
    x_col='path',
    y_col='class',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=SEED
)

test_generator = eval_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=None,
    x_col='path',
    y_col='class',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=SEED
)

# Vérifier les indices de classes
print("\nIndices des classes:")
class_indices = train_generator.class_indices
print(class_indices)
# Out:
# Found 7224 validated image filenames belonging to 6 classes.
# Found 676 validated image filenames belonging to 6 classes.
# Found 677 validated image filenames belonging to 6 classes.
#
# Indices des classes:
# {'bruised': 0, 'cracked': 1, 'rotten': 2, 'spotted': 3, 'unaffected': 4, 'unripe': 5}

# %%
# Définir des générateurs plus simples sans prétraitement complexe pour le débogage
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Simplement normaliser les valeurs de pixels
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# Version sans prétraitement complexe pour le débogage
train_generator = train_datagen.flow_from_directory(
    directory='african_plums_dataset/african_plums',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    shuffle=True,
    seed=SEED
)

validation_generator = train_datagen.flow_from_directory(
    directory='african_plums_dataset/african_plums',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    seed=SEED
)

# Vérifier les classes détectées par le générateur
print("\nClasses du générateur d'entraînement:")
train_classes = train_generator.class_indices
print(train_classes)
# Out:
# Found 3608 images belonging to 6 classes.
# Found 899 images belonging to 6 classes.
#
# Classes du générateur d'entraînement:
# {'bruised': 0, 'cracked': 1, 'rotten': 2, 'spotted': 3, 'unaffected': 4, 'unripe': 5}

# %%
# Correspondance indices-noms pour l'évaluation
class_names = list(class_indices.keys())

# %% [markdown]
# # <h2 align = "center">phase d'entrainement</h2>

# %% [markdown]
# # <h3 align = "center"> Chargement du modèle pré-entraîné (MobileNetV2) </h3>

# %%
# 5. Construction du modèle
from tensorflow.keras.regularizers import l1_l2,l2
# 5.1 Chargement du modèle pré-entraîné (MobileNetV2)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
for layer in base_model.layers:
    if hasattr(layer, 'kernel_regularizer'):
        layer.kernel_regularizer = l2(0.00005)

# 5.2 Ajout des couches personnalisées
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu',kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001))(x)
x = BatchNormalization(momentum=0.9)(x)  # Ajout de la normalisation par lots
x = Dropout(0.6)(x)
x = Dense(128, activation='relu',kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001))(x)
x = BatchNormalization(momentum=0.9)(x)  # Ajout de la normalisation par lots
x = Dropout(0.4)(x)
predictions = Dense(len(class_indices), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %% [markdown]
# # <h3 align = "center">Compilation du  et Utilisation de Focal Loss pour mieux gérer les classes déséquilibrées</h3>

# %%
# 5.3 Gel des couches du modèle de base
for layer in base_model.layers:
    layer.trainable = False

# 6. Compilation et entraînement du modèle
# 6.1 Compilation avec fonction de perte adaptée et taux d'apprentissage réduit
# Utilisation de Focal Loss pour mieux gérer les classes déséquilibrées
focal_loss = CategoricalFocalCrossentropy(gamma=2.0)

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss=focal_loss,  # Remplace 'categorical_crossentropy'
    metrics=['accuracy', 'AUC', 'Precision', 'Recall']  # Métriques supplémentaires
)

# %%
# 6.2 Définition des callbacks
checkpoint = ModelCheckpoint(
    'best_plum_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,  # Augmentation de la patience
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=10,
    min_lr=0.00001,
    verbose=1
)

callbacks = [checkpoint, early_stopping, reduce_lr]

# %% [markdown]
# # <h3 align = "center"> Calcul des poids de classes pour gérer le déséquilibre </h3>

# %%
# 6.3 Calcul des poids de classes pour gérer le déséquilibre
class_weights = {}
train_class_counts = np.bincount(train_generator.classes)
total_samples = train_generator.samples

for i, count in enumerate(train_class_counts):
    if count > 0:
        if class_names[i] in ['bruised', 'cracked']:
            # Pénaliser plus fortement les erreurs sur les classes minoritaires
            class_weights[i] = (total_samples / (len(train_class_counts) * count)) ** 1.5
        else:
            class_weights[i] = (total_samples / (len(train_class_counts) * count)) ** 1.0
    else:
        class_weights[i] = 1.0

print("\nPoids des classes pour l'entraînement:")
for i, cls in enumerate(train_generator.class_indices.keys()):
    print(f"{cls} (indice {i}): {class_weights[i]:.4f}")

# Visualiser les poids de classes
plt.figure(figsize=(10, 6))
class_labels = list(train_generator.class_indices.keys())
weights = [class_weights[i] for i in range(len(class_labels))]
sns.barplot(x=class_labels, y=weights)
plt.title('Poids appliqués à chaque classe pour compenser le déséquilibre')
plt.xlabel('Classe')
plt.ylabel('Poids')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('class_weights.png')
plt.close()
# Out:
# Poids des classes pour l'entraînement:
# bruised (indice 0): 3.6001
# cracked (indice 1): 9.9485
# rotten (indice 2): 1.0440
# spotted (indice 3): 0.9890
# unaffected (indice 4): 0.4367
# unripe (indice 5): 0.9097

# %%
# 6.4 Affichage du résumé du modèle
print("\nRésumé de l'architecture du modèle:")
model.summary()
# Out:
# Résumé de l'architecture du modèle:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 324, 324, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 162, 162, 32)         864       ['input_1[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 162, 162, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 162, 162, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 162, 162, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 162, 162, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 162, 162, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 162, 162, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 162, 162, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 162, 162, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 162, 162, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 162, 162, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 163, 163, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 81, 81, 96)           864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 81, 81, 96)           384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 81, 81, 96)           0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 81, 81, 24)           2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 81, 81, 24)           96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 81, 81, 144)          3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 81, 81, 144)          576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 81, 81, 144)          0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 81, 81, 144)          1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 81, 81, 144)          576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 81, 81, 144)          0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 81, 81, 24)           3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 81, 81, 24)           96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 81, 81, 24)           0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 81, 81, 144)          3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 81, 81, 144)          576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 81, 81, 144)          0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 83, 83, 144)          0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 41, 41, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 41, 41, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 41, 41, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 41, 41, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 41, 41, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 41, 41, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 41, 41, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 41, 41, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 41, 41, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 41, 41, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 41, 41, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 41, 41, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 41, 41, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 41, 41, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 41, 41, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 41, 41, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 41, 41, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 41, 41, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 41, 41, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 41, 41, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 41, 41, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 41, 41, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 41, 41, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 41, 41, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 41, 41, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 41, 41, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 43, 43, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 21, 21, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 21, 21, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 21, 21, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 21, 21, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 21, 21, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 21, 21, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 21, 21, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 21, 21, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 21, 21, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 21, 21, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 21, 21, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 21, 21, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 21, 21, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 21, 21, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 21, 21, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 21, 21, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 21, 21, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 21, 21, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 21, 21, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 21, 21, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 21, 21, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 21, 21, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 21, 21, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 21, 21, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 21, 21, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 21, 21, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 21, 21, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 21, 21, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 21, 21, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 21, 21, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 21, 21, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 21, 21, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 21, 21, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 21, 21, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 21, 21, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 21, 21, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 21, 21, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 21, 21, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 21, 21, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 21, 21, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 21, 21, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 21, 21, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 21, 21, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 21, 21, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 21, 21, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 21, 21, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 21, 21, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 21, 21, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 21, 21, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 21, 21, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 21, 21, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 21, 21, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 21, 21, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 21, 21, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 21, 21, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 21, 21, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 21, 21, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 21, 21, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 21, 21, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 21, 21, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 21, 21, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 23, 23, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 11, 11, 576)          5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 11, 11, 576)          2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 11, 11, 576)          0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 11, 11, 160)          92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 11, 11, 160)          640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 11, 11, 960)          153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 11, 11, 960)          3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 11, 11, 960)          0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 11, 11, 960)          8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 11, 11, 960)          3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 11, 11, 960)          0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 11, 11, 160)          153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 11, 11, 160)          640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 11, 11, 160)          0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 11, 11, 960)          153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 11, 11, 960)          3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 11, 11, 960)          0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 11, 11, 960)          8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 11, 11, 960)          3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 11, 11, 960)          0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 11, 11, 160)          153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 11, 11, 160)          640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 11, 11, 160)          0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 11, 11, 960)          153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 11, 11, 960)          3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 11, 11, 960)          0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 11, 11, 960)          8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 11, 11, 960)          3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 11, 11, 960)          0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 11, 11, 320)          307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 11, 11, 320)          1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 11, 11, 1280)         409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 11, 11, 1280)         5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 11, 11, 1280)         0         ['Conv_1_bn[0][0]']
#
#  global_average_pooling2d (  (None, 1280)                 0         ['out_relu[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)                  327936    ['global_average_pooling2d[0][
#                                                                     0]']
#
#  batch_normalization (Batch  (None, 256)                  1024      ['dense[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 256)                  0         ['batch_normalization[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  32896     ['dropout[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128)                  512       ['dense_1[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 6)                    774       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 2621126 (10.00 MB)
# Trainable params: 362374 (1.38 MB)
# Non-trainable params: 2258752 (8.62 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# # <h3 align = "center"> Première phase d'entraînement - uniquement les couches supérieures</h3>

# %%
# 7. Fine-tuning du modèle
# 7.1 Première phase d'entraînement - uniquement les couches supérieures

print("\nDébut de l'entraînement initial...")
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=75,  # Première phase d'entraînement
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Début de l'entraînement initial...
# Epoch 1/75
# 225/225 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.7879 - auc: 0.9638 - precision: 0.8477 - recall: 0.6851
# Epoch 1: val_accuracy improved from -inf to 0.58594, saving model to best_plum_model.h5
# /home/lontsi/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 225/225 [==============================] - 123s 540ms/step - loss: 0.1819 - accuracy: 0.7879 - auc: 0.9638 - precision: 0.8477 - recall: 0.6851 - val_loss: 0.2880 - val_accuracy: 0.5859 - val_auc: 0.8815 - val_precision: 0.6432 - val_recall: 0.4888 - lr: 1.0000e-04
# Epoch 2/75
# 225/225 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.7831 - auc: 0.9650 - precision: 0.8498 - recall: 0.6899
# Epoch 2: val_accuracy improved from 0.58594 to 0.60379, saving model to best_plum_model.h5
# 225/225 [==============================] - 141s 629ms/step - loss: 0.1790 - accuracy: 0.7831 - auc: 0.9650 - precision: 0.8498 - recall: 0.6899 - val_loss: 0.2779 - val_accuracy: 0.6038 - val_auc: 0.8902 - val_precision: 0.6676 - val_recall: 0.5201 - lr: 1.0000e-04
# Epoch 3/75
# 225/225 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.7965 - auc: 0.9643 - precision: 0.8543 - recall: 0.6924

# %% [markdown]
# # <h3 align = "center">Premier fine-tuning: dégel des dernières couches du modèle de base</h3>

# %%
# 7.2 Premier fine-tuning: dégel des dernières couches du modèle de base
print("\nDébut du premier fine-tuning...")
# Dégeler les derniers blocs du MobileNetV2
for layer in base_model.layers[-30:]:
    layer.trainable = True

# Recompiler avec un taux d'apprentissage plus faible
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE ),
    loss=focal_loss,
    metrics=['accuracy', 'AUC', 'Precision', 'Recall']
)

# Premier fine-tuning
fine_tuning_history1 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=35,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Début du premier fine-tuning...
# Epoch 1/35
# 225/225 [==============================] - ETA: 0s - loss: 0.6545 - accuracy: 0.4958 - auc: 0.8184 - precision: 0.6384 - recall: 0.2979
# Epoch 1: val_accuracy did not improve from 0.50112
# 225/225 [==============================] - 137s 596ms/step - loss: 0.6545 - accuracy: 0.4958 - auc: 0.8184 - precision: 0.6384 - recall: 0.2979 - val_loss: 1.0374 - val_accuracy: 0.4330 - val_auc: 0.7559 - val_precision: 0.4563 - val_recall: 0.4196 - lr: 1.0000e-04
# Epoch 2/35
# 225/225 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.5245 - auc: 0.8432 - precision: 0.6852 - recall: 0.3193
# Epoch 2: val_accuracy did not improve from 0.50112
# 225/225 [==============================] - 135s 598ms/step - loss: 0.6039 - accuracy: 0.5245 - auc: 0.8432 - precision: 0.6852 - recall: 0.3193 - val_loss: 0.9419 - val_accuracy: 0.4464 - val_auc: 0.7705 - val_precision: 0.4701 - val_recall: 0.4297 - lr: 1.0000e-04
# Epoch 3/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5793 - accuracy: 0.5387 - auc: 0.8596 - precision: 0.6946 - recall: 0.3388
# Epoch 3: val_accuracy did not improve from 0.50112
# 225/225 [==============================] - 128s 570ms/step - loss: 0.5793 - accuracy: 0.5387 - auc: 0.8596 - precision: 0.6946 - recall: 0.3388 - val_loss: 0.7392 - val_accuracy: 0.4788 - val_auc: 0.8162 - val_precision: 0.5417 - val_recall: 0.4498 - lr: 1.0000e-04
# Epoch 4/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5604 - accuracy: 0.5702 - auc: 0.8709 - precision: 0.7228 - recall: 0.3666
# Epoch 4: val_accuracy did not improve from 0.50112
# 225/225 [==============================] - 132s 589ms/step - loss: 0.5604 - accuracy: 0.5702 - auc: 0.8709 - precision: 0.7228 - recall: 0.3666 - val_loss: 0.6551 - val_accuracy: 0.4922 - val_auc: 0.8278 - val_precision: 0.5595 - val_recall: 0.4252 - lr: 1.0000e-04
# Epoch 5/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5446 - accuracy: 0.5894 - auc: 0.8801 - precision: 0.7471 - recall: 0.3898
# Epoch 5: val_accuracy did not improve from 0.50112
# 225/225 [==============================] - 134s 596ms/step - loss: 0.5446 - accuracy: 0.5894 - auc: 0.8801 - precision: 0.7471 - recall: 0.3898 - val_loss: 0.5956 - val_accuracy: 0.4978 - val_auc: 0.8489 - val_precision: 0.5809 - val_recall: 0.4208 - lr: 1.0000e-04
# Epoch 6/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5325 - accuracy: 0.5902 - auc: 0.8833 - precision: 0.7347 - recall: 0.3970
# Epoch 6: val_accuracy improved from 0.50112 to 0.53237, saving model to best_plum_model.h5
# 225/225 [==============================] - 137s 609ms/step - loss: 0.5325 - accuracy: 0.5902 - auc: 0.8833 - precision: 0.7347 - recall: 0.3970 - val_loss: 0.5387 - val_accuracy: 0.5324 - val_auc: 0.8668 - val_precision: 0.6286 - val_recall: 0.4118 - lr: 1.0000e-04
# Epoch 7/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5133 - accuracy: 0.6139 - auc: 0.8915 - precision: 0.7511 - recall: 0.4101
# Epoch 7: val_accuracy improved from 0.53237 to 0.55804, saving model to best_plum_model.h5
# 225/225 [==============================] - 134s 596ms/step - loss: 0.5133 - accuracy: 0.6139 - auc: 0.8915 - precision: 0.7511 - recall: 0.4101 - val_loss: 0.5433 - val_accuracy: 0.5580 - val_auc: 0.8723 - val_precision: 0.6197 - val_recall: 0.4565 - lr: 1.0000e-04
# Epoch 8/35
# 225/225 [==============================] - ETA: 0s - loss: 0.5004 - accuracy: 0.6225 - auc: 0.8987 - precision: 0.7674 - recall: 0.4290
# Epoch 8: val_accuracy improved from 0.55804 to 0.58817, saving model to best_plum_model.h5
# 225/225 [==============================] - 135s 599ms/step - loss: 0.5004 - accuracy: 0.6225 - auc: 0.8987 - precision: 0.7674 - recall: 0.4290 - val_loss: 0.5114 - val_accuracy: 0.5882 - val_auc: 0.8834 - val_precision: 0.6734 - val_recall: 0.4464 - lr: 1.0000e-04
# Epoch 9/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.6328 - auc: 0.9071 - precision: 0.7540 - recall: 0.4301
# Epoch 9: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 132s 585ms/step - loss: 0.4853 - accuracy: 0.6328 - auc: 0.9071 - precision: 0.7540 - recall: 0.4301 - val_loss: 0.5041 - val_accuracy: 0.5614 - val_auc: 0.8764 - val_precision: 0.6432 - val_recall: 0.4085 - lr: 1.0000e-04
# Epoch 10/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4737 - accuracy: 0.6392 - auc: 0.9074 - precision: 0.7744 - recall: 0.4502
# Epoch 10: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 130s 579ms/step - loss: 0.4737 - accuracy: 0.6392 - auc: 0.9074 - precision: 0.7744 - recall: 0.4502 - val_loss: 0.5053 - val_accuracy: 0.5558 - val_auc: 0.8738 - val_precision: 0.6320 - val_recall: 0.4408 - lr: 1.0000e-04
# Epoch 11/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4546 - accuracy: 0.6562 - auc: 0.9160 - precision: 0.7844 - recall: 0.4710
# Epoch 11: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 134s 594ms/step - loss: 0.4546 - accuracy: 0.6562 - auc: 0.9160 - precision: 0.7844 - recall: 0.4710 - val_loss: 0.4980 - val_accuracy: 0.5882 - val_auc: 0.8771 - val_precision: 0.6688 - val_recall: 0.4710 - lr: 1.0000e-04
# Epoch 12/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4413 - accuracy: 0.6748 - auc: 0.9203 - precision: 0.7804 - recall: 0.5036
# Epoch 12: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 137s 607ms/step - loss: 0.4413 - accuracy: 0.6748 - auc: 0.9203 - precision: 0.7804 - recall: 0.5036 - val_loss: 0.4956 - val_accuracy: 0.5614 - val_auc: 0.8694 - val_precision: 0.6579 - val_recall: 0.4464 - lr: 1.0000e-04
# Epoch 13/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4498 - accuracy: 0.6542 - auc: 0.9126 - precision: 0.7670 - recall: 0.4811
# Epoch 13: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 131s 582ms/step - loss: 0.4498 - accuracy: 0.6542 - auc: 0.9126 - precision: 0.7670 - recall: 0.4811 - val_loss: 0.4898 - val_accuracy: 0.5234 - val_auc: 0.8578 - val_precision: 0.6035 - val_recall: 0.3839 - lr: 1.0000e-04
# Epoch 14/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4214 - accuracy: 0.6787 - auc: 0.9234 - precision: 0.7849 - recall: 0.4967
# Epoch 14: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 138s 613ms/step - loss: 0.4214 - accuracy: 0.6787 - auc: 0.9234 - precision: 0.7849 - recall: 0.4967 - val_loss: 0.4722 - val_accuracy: 0.5491 - val_auc: 0.8748 - val_precision: 0.6545 - val_recall: 0.4420 - lr: 1.0000e-04
# Epoch 15/35
# 225/225 [==============================] - ETA: 0s - loss: 0.4157 - accuracy: 0.6918 - auc: 0.9284 - precision: 0.7968 - recall: 0.5153
# Epoch 15: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 131s 582ms/step - loss: 0.4157 - accuracy: 0.6918 - auc: 0.9284 - precision: 0.7968 - recall: 0.5153 - val_loss: 0.4841 - val_accuracy: 0.5112 - val_auc: 0.8629 - val_precision: 0.5812 - val_recall: 0.4074 - lr: 1.0000e-04
# Epoch 16/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.6915 - auc: 0.9320 - precision: 0.8035 - recall: 0.5395
# Epoch 16: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 133s 590ms/step - loss: 0.3940 - accuracy: 0.6915 - auc: 0.9320 - precision: 0.8035 - recall: 0.5395 - val_loss: 0.4665 - val_accuracy: 0.5435 - val_auc: 0.8689 - val_precision: 0.6143 - val_recall: 0.4319 - lr: 1.0000e-04
# Epoch 17/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3887 - accuracy: 0.7057 - auc: 0.9333 - precision: 0.8128 - recall: 0.5498
# Epoch 17: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 132s 588ms/step - loss: 0.3887 - accuracy: 0.7057 - auc: 0.9333 - precision: 0.8128 - recall: 0.5498 - val_loss: 0.4978 - val_accuracy: 0.5000 - val_auc: 0.8408 - val_precision: 0.5735 - val_recall: 0.3962 - lr: 1.0000e-04
# Epoch 18/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3880 - accuracy: 0.6943 - auc: 0.9281 - precision: 0.8015 - recall: 0.5395
# Epoch 18: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 130s 580ms/step - loss: 0.3880 - accuracy: 0.6943 - auc: 0.9281 - precision: 0.8015 - recall: 0.5395 - val_loss: 0.4599 - val_accuracy: 0.5190 - val_auc: 0.8603 - val_precision: 0.5818 - val_recall: 0.4129 - lr: 1.0000e-04
# Epoch 19/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.7160 - auc: 0.9376 - precision: 0.8095 - recall: 0.5548
# Epoch 19: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 133s 593ms/step - loss: 0.3730 - accuracy: 0.7160 - auc: 0.9376 - precision: 0.8095 - recall: 0.5548 - val_loss: 0.4443 - val_accuracy: 0.5792 - val_auc: 0.8751 - val_precision: 0.6360 - val_recall: 0.4777 - lr: 1.0000e-04
# Epoch 20/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3556 - accuracy: 0.7238 - auc: 0.9407 - precision: 0.8141 - recall: 0.5768
# Epoch 20: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 135s 599ms/step - loss: 0.3556 - accuracy: 0.7238 - auc: 0.9407 - precision: 0.8141 - recall: 0.5768 - val_loss: 0.4560 - val_accuracy: 0.5145 - val_auc: 0.8539 - val_precision: 0.5978 - val_recall: 0.4230 - lr: 1.0000e-04
# Epoch 21/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3559 - accuracy: 0.7060 - auc: 0.9396 - precision: 0.8147 - recall: 0.5679
# Epoch 21: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 133s 591ms/step - loss: 0.3559 - accuracy: 0.7060 - auc: 0.9396 - precision: 0.8147 - recall: 0.5679 - val_loss: 0.4998 - val_accuracy: 0.4754 - val_auc: 0.8124 - val_precision: 0.5552 - val_recall: 0.3594 - lr: 1.0000e-04
# Epoch 22/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3381 - accuracy: 0.7319 - auc: 0.9423 - precision: 0.8244 - recall: 0.5883
# Epoch 22: val_accuracy did not improve from 0.58817
# 225/225 [==============================] - 131s 584ms/step - loss: 0.3381 - accuracy: 0.7319 - auc: 0.9423 - precision: 0.8244 - recall: 0.5883 - val_loss: 0.4394 - val_accuracy: 0.5413 - val_auc: 0.8570 - val_precision: 0.5975 - val_recall: 0.4308 - lr: 1.0000e-04
# Epoch 23/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.7408 - auc: 0.9467 - precision: 0.8213 - recall: 0.5913
# Epoch 23: val_accuracy improved from 0.58817 to 0.60826, saving model to best_plum_model.h5
# 225/225 [==============================] - 136s 606ms/step - loss: 0.3277 - accuracy: 0.7408 - auc: 0.9467 - precision: 0.8213 - recall: 0.5913 - val_loss: 0.4029 - val_accuracy: 0.6083 - val_auc: 0.8818 - val_precision: 0.6657 - val_recall: 0.4955 - lr: 1.0000e-04
# Epoch 24/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3131 - accuracy: 0.7411 - auc: 0.9482 - precision: 0.8253 - recall: 0.6063
# Epoch 24: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 135s 599ms/step - loss: 0.3131 - accuracy: 0.7411 - auc: 0.9482 - precision: 0.8253 - recall: 0.6063 - val_loss: 0.4117 - val_accuracy: 0.5737 - val_auc: 0.8692 - val_precision: 0.6473 - val_recall: 0.4855 - lr: 1.0000e-04
# Epoch 25/35
# 225/225 [==============================] - ETA: 0s - loss: 0.3101 - accuracy: 0.7344 - auc: 0.9471 - precision: 0.8253 - recall: 0.6024
# Epoch 25: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 130s 577ms/step - loss: 0.3101 - accuracy: 0.7344 - auc: 0.9471 - precision: 0.8253 - recall: 0.6024 - val_loss: 0.3831 - val_accuracy: 0.5938 - val_auc: 0.8835 - val_precision: 0.6600 - val_recall: 0.4810 - lr: 1.0000e-04
# Epoch 26/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.7620 - auc: 0.9535 - precision: 0.8415 - recall: 0.6398
# Epoch 26: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 136s 603ms/step - loss: 0.2952 - accuracy: 0.7620 - auc: 0.9535 - precision: 0.8415 - recall: 0.6398 - val_loss: 0.3736 - val_accuracy: 0.6071 - val_auc: 0.8893 - val_precision: 0.6796 - val_recall: 0.5067 - lr: 1.0000e-04
# Epoch 27/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2927 - accuracy: 0.7508 - auc: 0.9521 - precision: 0.8360 - recall: 0.6231
# Epoch 27: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 132s 585ms/step - loss: 0.2927 - accuracy: 0.7508 - auc: 0.9521 - precision: 0.8360 - recall: 0.6231 - val_loss: 0.3850 - val_accuracy: 0.5692 - val_auc: 0.8732 - val_precision: 0.6499 - val_recall: 0.4621 - lr: 1.0000e-04
# Epoch 28/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2911 - accuracy: 0.7322 - auc: 0.9465 - precision: 0.8129 - recall: 0.6086
# Epoch 28: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 131s 582ms/step - loss: 0.2911 - accuracy: 0.7322 - auc: 0.9465 - precision: 0.8129 - recall: 0.6086 - val_loss: 0.3803 - val_accuracy: 0.5502 - val_auc: 0.8722 - val_precision: 0.6217 - val_recall: 0.4475 - lr: 1.0000e-04
# Epoch 29/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2757 - accuracy: 0.7684 - auc: 0.9534 - precision: 0.8339 - recall: 0.6512
# Epoch 29: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 132s 586ms/step - loss: 0.2757 - accuracy: 0.7684 - auc: 0.9534 - precision: 0.8339 - recall: 0.6512 - val_loss: 0.3908 - val_accuracy: 0.5681 - val_auc: 0.8662 - val_precision: 0.6580 - val_recall: 0.4788 - lr: 1.0000e-04
# Epoch 30/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2633 - accuracy: 0.7862 - auc: 0.9594 - precision: 0.8540 - recall: 0.6562
# Epoch 30: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 133s 592ms/step - loss: 0.2633 - accuracy: 0.7862 - auc: 0.9594 - precision: 0.8540 - recall: 0.6562 - val_loss: 0.3763 - val_accuracy: 0.5681 - val_auc: 0.8702 - val_precision: 0.6442 - val_recall: 0.4688 - lr: 1.0000e-04
# Epoch 31/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.7659 - auc: 0.9569 - precision: 0.8371 - recall: 0.6464
# Epoch 31: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 134s 594ms/step - loss: 0.2627 - accuracy: 0.7659 - auc: 0.9569 - precision: 0.8371 - recall: 0.6464 - val_loss: 0.3821 - val_accuracy: 0.5569 - val_auc: 0.8521 - val_precision: 0.6554 - val_recall: 0.4096 - lr: 1.0000e-04
# Epoch 32/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.7848 - auc: 0.9594 - precision: 0.8466 - recall: 0.6651
# Epoch 32: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 134s 597ms/step - loss: 0.2538 - accuracy: 0.7848 - auc: 0.9594 - precision: 0.8466 - recall: 0.6651 - val_loss: 0.4131 - val_accuracy: 0.5301 - val_auc: 0.8323 - val_precision: 0.6096 - val_recall: 0.4252 - lr: 1.0000e-04
# Epoch 33/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2485 - accuracy: 0.7737 - auc: 0.9603 - precision: 0.8519 - recall: 0.6693
# Epoch 33: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 130s 578ms/step - loss: 0.2485 - accuracy: 0.7737 - auc: 0.9603 - precision: 0.8519 - recall: 0.6693 - val_loss: 0.3600 - val_accuracy: 0.5636 - val_auc: 0.8711 - val_precision: 0.6202 - val_recall: 0.4721 - lr: 1.0000e-04
# Epoch 34/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2318 - accuracy: 0.7923 - auc: 0.9647 - precision: 0.8515 - recall: 0.6865
# Epoch 34: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 134s 597ms/step - loss: 0.2318 - accuracy: 0.7923 - auc: 0.9647 - precision: 0.8515 - recall: 0.6865 - val_loss: 0.3538 - val_accuracy: 0.5882 - val_auc: 0.8718 - val_precision: 0.6292 - val_recall: 0.4810 - lr: 1.0000e-04
# Epoch 35/35
# 225/225 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.7790 - auc: 0.9573 - precision: 0.8397 - recall: 0.6693
# Epoch 35: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 135s 601ms/step - loss: 0.2395 - accuracy: 0.7790 - auc: 0.9573 - precision: 0.8397 - recall: 0.6693 - val_loss: 0.3692 - val_accuracy: 0.5335 - val_auc: 0.8571 - val_precision: 0.6082 - val_recall: 0.4330 - lr: 1.0000e-04
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # <h3 align = "center">Deuxième fine-tuning: dégel complet</h3>

# %%
# 7.3 Deuxième fine-tuning: dégel complet
print("\nDébut du deuxième fine-tuning avec modèle complètement dégelé...")
# Dégeler tous les layers du modèle de base
for layer in base_model.layers:
    layer.trainable = True

model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE ),
    loss=focal_loss,
    metrics=['accuracy', 'AUC', 'Precision', 'Recall']
)

# Deuxième fine-tuning
fine_tuning_history2 = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=25,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE,
    callbacks=callbacks,
    class_weight=class_weights,
    verbose=1
)
# Out:
# Début du deuxième fine-tuning avec modèle complètement dégelé...
# Epoch 1/25
# 225/225 [==============================] - ETA: 0s - loss: 0.3579 - accuracy: 0.6058 - auc: 0.8935 - precision: 0.7046 - recall: 0.4582
# Epoch 1: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 315s 1s/step - loss: 0.3579 - accuracy: 0.6058 - auc: 0.8935 - precision: 0.7046 - recall: 0.4582 - val_loss: 0.3449 - val_accuracy: 0.5982 - val_auc: 0.8703 - val_precision: 0.6946 - val_recall: 0.4721 - lr: 1.0000e-04
# Epoch 2/25
# 225/225 [==============================] - ETA: 0s - loss: 0.2948 - accuracy: 0.6551 - auc: 0.9182 - precision: 0.7668 - recall: 0.5117
# Epoch 2: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 321s 1s/step - loss: 0.2948 - accuracy: 0.6551 - auc: 0.9182 - precision: 0.7668 - recall: 0.5117 - val_loss: 0.4010 - val_accuracy: 0.5458 - val_auc: 0.8167 - val_precision: 0.6182 - val_recall: 0.4029 - lr: 1.0000e-04
# Epoch 3/25
# 225/225 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.6715 - auc: 0.9252 - precision: 0.7780 - recall: 0.5248
# Epoch 3: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 346s 2s/step - loss: 0.2797 - accuracy: 0.6715 - auc: 0.9252 - precision: 0.7780 - recall: 0.5248 - val_loss: 0.3473 - val_accuracy: 0.5525 - val_auc: 0.8541 - val_precision: 0.6385 - val_recall: 0.4219 - lr: 1.0000e-04
# Epoch 4/25
# 225/225 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.7004 - auc: 0.9356 - precision: 0.7955 - recall: 0.5587
# Epoch 4: val_accuracy did not improve from 0.60826
# 225/225 [==============================] - 344s 2s/step - loss: 0.2585 - accuracy: 0.7004 - auc: 0.9356 - precision: 0.7955 - recall: 0.5587 - val_loss: 0.3442 - val_accuracy: 0.5714 - val_auc: 0.8685 - val_precision: 0.6331 - val_recall: 0.4777 - lr: 1.0000e-04
# Epoch 5/25
#  27/225 [==>...........................] - ETA: 6:35 - loss: 0.2277 - accuracy: 0.7616 - auc: 0.9529 - precision: 0.8259 - recall: 0.6042

# %% [markdown]
# # <h3 align = "center"> Évaluation sur l'ensemble de validation </h3>

# %%
# 7.4 Évaluation sur l'ensemble de validation
print("\nÉvaluation du modèle sur l'ensemble de validation:")
model.load_weights('best_plum_model.h5')  # Charger le meilleur modèle
validation_results = model.evaluate(validation_generator)
print(f"Résultats sur l'ensemble de validation:")
print(f"Loss: {validation_results[0]:.4f}")
print(f"Accuracy: {validation_results[1]:.4f}")
print(f"AUC: {validation_results[2]:.4f}")
print(f"Precision: {validation_results[3]:.4f}")
print(f"Recall: {validation_results[4]:.4f}")
# Out:
# Évaluation du modèle sur l'ensemble de validation:
# 57/57 [==============================] - 18s 305ms/step - loss: 0.2871 - accuracy: 0.5795 - auc: 0.8865 - precision: 0.6547 - recall: 0.5061
# Résultats sur l'ensemble de validation:
# Loss: 0.2871
# Accuracy: 0.5795
# AUC: 0.8865
# Precision: 0.6547
# Recall: 0.5061

# %% [markdown]
# # <h3 align = "center"> Évaluation sur l'ensemble de test </h3>

# %%
# 8. Évaluation sur l'ensemble de test
# 8.1 Après le fine-tuning complet, évaluer sur l'ensemble de test indépendant

print("\nÉvaluation finale sur l'ensemble de test (données non vues pendant l'entraînement):")
model.load_weights('best_plum_model.h5')  # Charger le meilleur modèle
test_results = model.evaluate(test_generator)

print(f"Résultats sur l'ensemble de test:")
print(f"Loss: {test_results[0]:.4f}")
print(f"Accuracy: {test_results[1]:.4f}")
print(f"AUC: {test_results[2]:.4f}")
print(f"Precision: {test_results[3]:.4f}")
print(f"Recall: {test_results[4]:.4f}")

# 8.2 Matrice de confusion et rapport de classification détaillé
y_pred = []
y_true = []

# Prédire sur l'ensemble de test
for i in range(len(test_generator)):
    if i >= test_generator.samples // BATCH_SIZE + (1 if test_generator.samples % BATCH_SIZE > 0 else 0):
        break
    X, y = next(test_generator)
    y_pred.extend(np.argmax(model.predict(X), axis=1))
    y_true.extend(np.argmax(y, axis=1))

# Création du rapport de classification
print("\nRapport de classification sur l'ensemble de test:")
print(classification_report(y_true, y_pred, target_names=class_names))

# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matrice de confusion sur l\'ensemble de test')
plt.ylabel('Vérité terrain')
plt.xlabel('Prédiction')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('confusion_matrix_test.png')
plt.close()
# Out:
# Évaluation finale sur l'ensemble de test (données non vues pendant l'entraînement):
# 43/43 [==============================] - 10s 225ms/step - loss: 0.1830 - accuracy: 0.8272 - auc: 0.9674 - precision: 0.8718 - recall: 0.7637
# Résultats sur l'ensemble de test:
# Loss: 0.1830
# Accuracy: 0.8272
# AUC: 0.9674
# Precision: 0.8718
# Recall: 0.7637
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 233ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 316ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 274ms/step
# 1/1 [==============================] - 0s 104ms/step
#
# Rapport de classification sur l'ensemble de test:
#               precision    recall  f1-score   support
#
#      bruised       0.64      0.77      0.70        48
#      cracked       0.60      1.00      0.75        24
#       rotten       0.93      0.87      0.90       108
#      spotted       0.68      0.77      0.72       114
#   unaffected       0.92      0.82      0.87       259
#       unripe       0.88      0.85      0.86       124
#
#     accuracy                           0.83       677
#    macro avg       0.78      0.85      0.80       677
# weighted avg       0.84      0.83      0.83       677

# %% [markdown]
# # <h3 align = "center">visualisation des courbe d'entrainement </h3>

# %%
def plot_smooth_training_history(history, title_suffix="", window_size=5, show=True):
    plt.figure(figsize=(20, 10))
    
    # Préparation des données
    combined_history = {}
    if isinstance(history, list):
        combined_epochs = 0
        for h in history:
            for metric in h.history.keys():
                if metric not in combined_history:
                    combined_history[metric] = []
                combined_history[metric].extend(h.history[metric])
            combined_epochs += len(h.history['accuracy'])
        epochs_range = range(1, combined_epochs + 1)
    else:
        combined_history = history.history
        epochs_range = range(1, len(history.history['accuracy']) + 1)
    
    # Fonction de lissage
    def smooth_curve(points):
        return pd.Series(points).rolling(window=window_size, center=True).mean().fillna(method='bfill').fillna(method='ffill').values
    
    # Précision
    plt.subplot(2, 2, 1)
    plt.plot(epochs_range, smooth_curve(combined_history['accuracy']), label='Train', linewidth=2)
    plt.plot(epochs_range, smooth_curve(combined_history['val_accuracy']), label='Validation', linewidth=2)
    plt.title(f'Précision du modèle {title_suffix}')
    plt.ylabel('Précision')
    plt.xlabel('Époque')
    plt.legend(loc='lower right')
    plt.grid(True)
    
    # Perte
    plt.subplot(2, 2, 2)
    plt.plot(epochs_range, smooth_curve(combined_history['loss']), label='Train', linewidth=2)
    plt.plot(epochs_range, smooth_curve(combined_history['val_loss']), label='Validation', linewidth=2)
    plt.title(f'Perte du modèle {title_suffix}')
    plt.ylabel('Perte')
    plt.xlabel('Époque')
    plt.legend(loc='upper right')
    plt.grid(True)
    
    # AUC
    if 'auc' in combined_history:
        plt.subplot(2, 2, 3)
        plt.plot(epochs_range, smooth_curve(combined_history['auc']), label='Train', linewidth=2)
        plt.plot(epochs_range, smooth_curve(combined_history['val_auc']), label='Validation', linewidth=2)
        plt.title(f'AUC {title_suffix}')
        plt.ylabel('AUC')
        plt.xlabel('Époque')
        plt.legend(loc='lower right')
        plt.grid(True)
    
    # Précision et Rappel
    if 'precision' in combined_history and 'recall' in combined_history:
        plt.subplot(2, 2, 4)
        plt.plot(epochs_range, smooth_curve(combined_history['precision']), label='Précision (Train)', linewidth=2)
        plt.plot(epochs_range, smooth_curve(combined_history['val_precision']), label='Précision (Val)', linewidth=2)
        plt.plot(epochs_range, smooth_curve(combined_history['recall']), label='Rappel (Train)', linewidth=2)
        plt.plot(epochs_range, smooth_curve(combined_history['val_recall']), label='Rappel (Val)', linewidth=2)
        plt.title(f'Précision et Rappel {title_suffix}')
        plt.ylabel('Valeur')
        plt.xlabel('Époque')
        plt.legend(loc='lower right')
        plt.grid(True)
    
    plt.tight_layout()
    
    # Enregistrer l'image
    plt.savefig(f'smooth_training_history{title_suffix.replace(" ", "_")}.png', dpi=300)
    
    # Afficher l'image au lieu de la fermer si demandé
    if show:
        plt.show()
    else:
        plt.close()

# Utilisation dans le notebook:
plot_smooth_training_history(combined_history_list, title_suffix=" - Entraînement Complet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 79
#      76         plt.close()
#      78 # Utilisation dans le notebook:
# ---> 79 plot_smooth_training_history(combined_history_list, title_suffix=" - Entraînement Complet")
#
# NameError: name 'combined_history_list' is not defined

# %% [markdown]
# # <h3 align = "center">Matrice de confusion </h3>

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Charger le meilleur modèle
model.load_weights('best_plum_model.h5')

# Prédire sur l'ensemble de test
y_pred = []
y_true = []

# Réinitialiser le générateur
test_generator.reset()

# Récupérer les prédictions pour l'ensemble de test complet
for i in range(len(test_generator)):
    if i >= test_generator.samples // BATCH_SIZE + (1 if test_generator.samples % BATCH_SIZE > 0 else 0):
        break
    X, y = next(test_generator)
    y_pred.extend(np.argmax(model.predict(X), axis=1))
    y_true.extend(np.argmax(y, axis=1))

# Obtenir les noms des classes
class_names = list(test_generator.class_indices.keys())

# Générer le rapport de classification
report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

# Afficher la précision, le rappel et le F1-score pour chaque classe
print("Précision par classe:")
for cls_name, metrics in report.items():
    if cls_name in class_names:
        print(f"{cls_name}:")
        print(f"  - Précision: {metrics['precision']:.4f}")
        print(f"  - Rappel: {metrics['recall']:.4f}")
        print(f"  - F1-score: {metrics['f1-score']:.4f}")
        print(f"  - Support: {metrics['support']} échantillons")
        print()

# Visualisation sous forme de graphique
plt.figure(figsize=(12, 8))
classes = list(report.keys())[:len(class_names)]
precision = [report[cls]['precision'] for cls in classes]
recall = [report[cls]['recall'] for cls in classes]
f1_score = [report[cls]['f1-score'] for cls in classes]

x = np.arange(len(classes))
width = 0.25

plt.bar(x - width, precision, width, label='Précision')
plt.bar(x, recall, width, label='Rappel')
plt.bar(x + width, f1_score, width, label='F1-score')

plt.ylabel('Score')
plt.title('Métriques par classe')
plt.xticks(x, classes, rotation=45)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ajouter les valeurs sur chaque barre
for i, v in enumerate(precision):
    plt.text(i - width, v + 0.02, f'{v:.2f}', ha='center')
for i, v in enumerate(recall):
    plt.text(i, v + 0.02, f'{v:.2f}', ha='center')
for i, v in enumerate(f1_score):
    plt.text(i + width, v + 0.02, f'{v:.2f}', ha='center')

plt.tight_layout()
plt.savefig('class_metrics.png', dpi=300)
plt.show()

# Matrice de confusion
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matrice de confusion')
plt.ylabel('Vérité terrain')
plt.xlabel('Prédiction')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('confusion_matrix_detailed.png', dpi=300)
plt.show()
# Out:
# 1/1 [==============================] - 0s 309ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 317ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 308ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 97ms/step
# Précision par classe:
# bruised:
#   - Précision: 0.6800
#   - Rappel: 0.7083
#   - F1-score: 0.6939
#   - Support: 48.0 échantillons
#
# cracked:
#   - Précision: 0.6154
#   - Rappel: 1.0000
#   - F1-score: 0.7619
#   - Support: 24.0 échantillons
#
# rotten:
#   - Précision: 0.8952
#   - Rappel: 0.8704
#   - F1-score: 0.8826
#   - Support: 108.0 échantillons
#
# spotted:
#   - Précision: 0.6979
#   - Rappel: 0.5877
#   - F1-score: 0.6381
#   - Support: 114.0 échantillons
#
# unaffected:
#   - Précision: 0.8789
#   - Rappel: 0.8687
#   - F1-score: 0.8738
#   - Support: 259.0 échantillons
#
# unripe:
#   - Précision: 0.8321
#   - Rappel: 0.8790
#   - F1-score: 0.8549
#   - Support: 124.0 échantillons

# %% [markdown]
# # <h3 align = "center">precision sur chaque classse</h3>

# %%
# Calculer directement la précision par classe à partir de la matrice de confusion
precision_per_class = np.diag(cm) / np.sum(cm, axis=0)

# Afficher la précision par classe
print("\nPrécision calculée directement pour chaque classe:")
for i, cls_name in enumerate(class_names):
    print(f"{cls_name}: {precision_per_class[i]:.4f}")

# Afficher le nombre d'échantillons correctement classifiés par classe
print("\nNombre d'échantillons correctement classifiés par classe:")
for i, cls_name in enumerate(class_names):
    print(f"{cls_name}: {cm[i, i]} sur {np.sum(cm[i, :])} échantillons")
# Out:
# Précision calculée directement pour chaque classe:
# bruised: 0.6800
# cracked: 0.6154
# rotten: 0.8952
# spotted: 0.6979
# unaffected: 0.8789
# unripe: 0.8321
#
# Nombre d'échantillons correctement classifiés par classe:
# bruised: 34 sur 48 échantillons
# cracked: 24 sur 24 échantillons
# rotten: 94 sur 108 échantillons
# spotted: 67 sur 114 échantillons
# unaffected: 225 sur 259 échantillons
# unripe: 109 sur 124 échantillons

# %%
from sklearn.metrics import roc_curve, auc
from itertools import cycle

# Récupérer les probabilités prédites
y_pred_proba = []
test_generator.reset()
for i in range(len(test_generator)):
    if i >= test_generator.samples // BATCH_SIZE + (1 if test_generator.samples % BATCH_SIZE > 0 else 0):
        break
    X, y = next(test_generator)
    y_pred_proba.extend(model.predict(X))

y_pred_proba = np.array(y_pred_proba)
y_test_onehot = to_categorical(y_true, num_classes=len(class_names))

# Tracer les courbes ROC pour chaque classe
plt.figure(figsize=(12, 8))
colors = cycle(['blue', 'red', 'green', 'orange', 'purple', 'brown'])
for i, color in zip(range(len(class_names)), colors):
    fpr, tpr, _ = roc_curve(y_test_onehot[:, i], y_pred_proba[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2,
             label=f'ROC classe {class_names[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taux de faux positifs')
plt.ylabel('Taux de vrais positifs')
plt.title('Courbes ROC par classe')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.savefig('roc_curves.png', dpi=300)
plt.show()
# Out:
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 283ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 108ms/step
